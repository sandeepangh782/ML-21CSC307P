# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/fake-and-real-news-dataset/True.csv
# /kaggle/input/fake-and-real-news-dataset/Fake.csv

# %%
truenews = pd.read_csv('/kaggle/input/fake-and-real-news-dataset/True.csv')
fakenews = pd.read_csv('/kaggle/input/fake-and-real-news-dataset/Fake.csv')

# %%
fakenews.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
truenews.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fakenews.describe()
# Out:
#                                                     title   text subject  \
# count                                               23481  23481   23481
# unique                                              17903  17455       6
# top     MEDIA IGNORES Time That Bill Clinton FIRED His...           News
# freq                                                    6    626    9050
#
#                 date
# count          23481
# unique          1681
# top     May 10, 2017
# freq              46

# %%
truenews.describe()
# Out:
#                                                     title  \
# count                                               21417
# unique                                              20826
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14
#
#                                                      text       subject  \
# count                                               21417         21417
# unique                                              21192             2
# top     (Reuters) - Highlights for U.S. President Dona...  politicsNews
# freq                                                    8         11272
#
#                       date
# count                21417
# unique                 716
# top     December 20, 2017
# freq                   182

# %%
truenews['True/Fake']='True'
fakenews['True/Fake']='Fake'

# %%
# Combine the 2 DataFrames into a single data frame
news = pd.concat([truenews, fakenews])
news["Article"] = news["title"] + news["text"]
news.sample(frac = 1) #Shuffle 100%
# Out:
#                                                    title  \
# 19085  Merkel hangs on to power but bleeds support to...
# 11780  #BoycottStarbucks…CEO Puts Leftist Agenda Over...
# 14096  FIRST It Was”Low Energy Jeb” And “Lyin Ted,” T...
# 739    Tax-cut debate in U.S. Congress swings to Sena...
# 17801  YIKES! ACADEMY AWARD WINNING Actor Starring In...
# ...                                                  ...
# 1775   Trump likely to visit China during November As...
# 14615  Cambodia's main opposition party dissolved by ...
# 6008   Trump names Cheryl LaFleur acting chairman of ...
# 4934    Trump Contradicts Himself In Latest Whiny Twe...
# 2603   Kushner, in statement, says 'I did not collude...
#
#                                                     text       subject  \
# 19085  BERLIN (Reuters) - German Chancellor Angela Me...     worldnews
# 11780  Starbucks has pledged to hire 10,000 refugees ...      politics
# 14096  What do you think about Hillary s new nickname...      politics
# 739    WASHINGTON (Reuters) - A U.S. Senate tax-cut b...  politicsNews
# 17801  Batman fans who have been looking forward to t...     left-news
# ...                                                  ...           ...
# 1775   WASHINGTON (Reuters) - U.S. President Donald T...  politicsNews
# 14615  PHNOM PENH (Reuters) - Cambodia s highest cour...     worldnews
# 6008   (Reuters) - President Donald Trump on Thursday...  politicsNews
# 4934   In case you haven t noticed, because maybe you...          News
# 2603   WASHINGTON (Reuters) - President Donald Trump’...  politicsNews
#
#                       date True/Fake  \
# 19085  September 23, 2017       True
# 11780         Jan 30, 2017      Fake
# 14096         Apr 17, 2016      Fake
# 739      November 8, 2017       True
# 17801         Oct 17, 2017      Fake
# ...                    ...       ...
# 1775   September 12, 2017       True
# 14615   November 16, 2017       True
# 6008     January 26, 2017       True
# 4934       August 23, 2016      Fake
# 2603        July 24, 2017       True
#
#                                                  Article
# 19085  Merkel hangs on to power but bleeds support to...
# 11780  #BoycottStarbucks…CEO Puts Leftist Agenda Over...
# 14096  FIRST It Was”Low Energy Jeb” And “Lyin Ted,” T...
# 739    Tax-cut debate in U.S. Congress swings to Sena...
# 17801  YIKES! ACADEMY AWARD WINNING Actor Starring In...
# ...                                                  ...
# 1775   Trump likely to visit China during November As...
# 14615  Cambodia's main opposition party dissolved by ...
# 6008   Trump names Cheryl LaFleur acting chairman of ...
# 4934    Trump Contradicts Himself In Latest Whiny Twe...
# 2603   Kushner, in statement, says 'I did not collude...
#
# [44898 rows x 6 columns]

# %%
#Data Cleaning
from nltk.corpus import stopwords
import string

# %%
def process_text(s):

    # Check string to see if they are a punctuation
    nopunc = [char for char in s if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Convert string to lowercase and remove stopwords
    clean_string = [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    return clean_string

# %%
# Tokenize the Article
#rerun, takes LOOOONG
news['Clean Text'] = news['Article'].apply(process_text)

# %%
news.sample(5)
# Out:
#                                                    title  \
# 7923    Iowa Voters Couldn’t Tell The Difference Betw...
# 8730   A festival air, and unease, hang over pre-conv...
# 15814  Iraqi forces capture Akkas gas field from Isla...
# 6924   Former astronaut Buzz Aldrin to stay in New Ze...
# 16468  BREAKING: Did Hillary’s Unsecured CLASSIFIED E...
#
#                                                     text          subject  \
# 7923   It can likely be said that Iowa is one of the ...             News
# 8730   CLEVELAND (Reuters) - East 4th Street, emblema...     politicsNews
# 15814  BAGHDAD (Reuters) - Iraqi forces captured the ...        worldnews
# 6924   WELLINGTON (Reuters) - Former U.S. astronaut B...     politicsNews
# 16468  Will the State Department ever tell the truth ...  Government News
#
#                     date True/Fake  \
# 7923   February 22, 2016      Fake
# 8730      July 17, 2016       True
# 15814  November 2, 2017       True
# 6924   December 4, 2016       True
# 16468        Aug 8, 2016      Fake
#
#                                                  Article  \
# 7923    Iowa Voters Couldn’t Tell The Difference Betw...
# 8730   A festival air, and unease, hang over pre-conv...
# 15814  Iraqi forces capture Akkas gas field from Isla...
# 6924   Former astronaut Buzz Aldrin to stay in New Ze...
# 16468  BREAKING: Did Hillary’s Unsecured CLASSIFIED E...
#
#                                               Clean Text
# 7923   [Iowa, Voters, Couldn’t, Tell, Difference, Ben...
# 8730   [festival, air, unease, hang, preconvention, C...
# 15814  [Iraqi, forces, capture, Akkas, gas, field, Is...
# 6924   [Former, astronaut, Buzz, Aldrin, stay, New, Z...
# 16468  [BREAKING, Hillary’s, Unsecured, CLASSIFIED, E...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_transformer = CountVectorizer(analyzer=process_text).fit(news['Clean Text'])

print(len(bow_transformer.vocabulary_)) #Total vocab words
# Out:
# 39099

# %%
#Bag-of-Words (bow) transform the entire DataFrame of text
news_bow = bow_transformer.transform(news['Clean Text'])

# %%
print('Shape of Sparse Matrix: ', news_bow.shape)
print('Amount of Non-Zero occurences: ', news_bow.nnz)
# Out:
# Shape of Sparse Matrix:  (44898, 39099)
# Amount of Non-Zero occurences:  44898

# %%
sparsity = (100.0 * news_bow.nnz / (news_bow.shape[0] * news_bow.shape[1]))
print('sparsity: {}'.format(round(sparsity)))
# Out:
# sparsity: 0

# %%
#TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer().fit(news_bow)
news_tfidf = tfidf_transformer.transform(news_bow)
print(news_tfidf.shape)
# Out:
# (44898, 39099)

# %%
#Train Naive Bayes Model
from sklearn.naive_bayes import MultinomialNB
fakenews_detect_model = MultinomialNB().fit(news_tfidf, news['True/Fake'])

# %%
#Model Evaluation
predictions = fakenews_detect_model.predict(news_tfidf)
print(predictions)
# Out:
# ['True' 'True' 'True' ... 'Fake' 'Fake' 'Fake']

# %%
from sklearn.metrics import classification_report
print (classification_report(news['True/Fake'], predictions))
# Out:
#               precision    recall  f1-score   support
#
#         Fake       1.00      1.00      1.00     23481
#         True       1.00      1.00      1.00     21417
#
#     accuracy                           1.00     44898
#    macro avg       1.00      1.00      1.00     44898
# weighted avg       1.00      1.00      1.00     44898

# %%
from sklearn.model_selection import train_test_split

news_train, news_test, text_train, text_test = train_test_split(news['Article'], news['True/Fake'], test_size=0.3)

print(len(news_train), len(news_test), len(news_train) + len(news_test))
# Out:
# 31428 13470 44898

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('bow', CountVectorizer(analyzer=process_text)),  
    ('tfidf', TfidfTransformer()),  
    ('classifier', MultinomialNB()),  
])
pipeline.fit(news_train,text_train)
# Out:
# Pipeline(memory=None,
#          steps=[('bow',
#                  CountVectorizer(analyzer=<function process_text at 0x7ff43feaa6a8>,
#                                  binary=False, decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=None)),
#                 ('tfidf',
#                  TfidfTransformer(norm='l2', smooth_idf=True,
#                                   sublinear_tf=False, use_idf=True)),
#                 ('classifier',
#                  MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))],
#          verbose=False)

# %%
prediction = pipeline.predict(news_test)

# %%
print(classification_report(prediction,text_test))
# Out:
#               precision    recall  f1-score   support
#
#         Fake       0.96      0.98      0.97      6905
#         True       0.98      0.95      0.97      6565
#
#     accuracy                           0.97     13470
#    macro avg       0.97      0.97      0.97     13470
# weighted avg       0.97      0.97      0.97     13470
